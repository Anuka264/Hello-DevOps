# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuka264/Hello-DevOps/blob/main/CSV101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("anu")
x = 5
z = 10
z += x
print(z)
! pwd
# Out:
# anu
# 15
# /content
